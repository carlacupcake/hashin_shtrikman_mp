# %% [markdown]
# ## Testing the Object Oriented Paradigm

# %%
from ga_params_class import GAParams
from hashin_sktrikman_class import HashinShtrikman
from population_class import Population
from genetic_string_class import GeneticString
from user_input_class import UserInput
from user_input_class import DEFAULT_USER_INPUT

# %%
# USER INPUT
user_input = DEFAULT_USER_INPUT

# %%
# Testing without calls to generate final dict (faster)
import json
consolidated_dict = {}
with open("test_final_dict") as f:
    consolidated_dict = json.load(f)

# %%
# Testing with all possible property_docs
HS = HashinShtrikman(api_key="uJpFxJJGKCSp9s1shwg9HmDuNjCDfWbM")
#consolidated_dict = HS.generate_final_dict(total_docs=50)

# %%
# Testing with all possible property_docs
HS.set_HS_optim_params()
HS.print_table_of_best_designs()
HS.plot_optimization_results()
mat_1_ids, mat_2_ids = HS.get_material_matches()

print("Material 1 Matches:")
print(mat_1_ids)
print("Material 2 Matches:")
print(mat_2_ids)

# TODO Go back and edits lines 287-289 in hashin_shtrikman_class.py !!!
# Out:
# Generation 0 of 5000
# Generation 1 of 5000
# Generation 2 of 5000
# Generation 3 of 5000
# Generation 4 of 5000
# Generation 5 of 5000
# Generation 6 of 5000
# Generation 7 of 5000
# Generation 8 of 5000
# Generation 9 of 5000
# Generation 10 of 5000
# Generation 11 of 5000
# Generation 12 of 5000
# Generation 13 of 5000
# Generation 14 of 5000
# Generation 15 of 5000
# Generation 16 of 5000
# Generation 17 of 5000
# Generation 18 of 5000
# Generation 19 of 5000
# Generation 20 of 5000
# Generation 21 of 5000
# Generation 22 of 5000
# Generation 23 of 5000
# Generation 24 of 5000
# Generation 25 of 5000
# Generation 26 of 5000
# Generation 27 of 5000
# Generation 28 of 5000
# Generation 29 of 5000
# Generation 30 of 5000
# Generation 31 of 5000
# Generation 32 of 5000
# Generation 33 of 5000
# Generation 34 of 5000
# Generation 35 of 5000
# Generation 36 of 5000
# Generation 37 of 5000
# Generation 38 of 5000
# Generation 39 of 5000
# Generation 40 of 5000
# Generation 41 of 5000
# ...

# %%
# Testing with subset of possible property_docs
api_key="uJpFxJJGKCSp9s1shwg9HmDuNjCDfWbM"
mp_contribs_project="carrier_transport"

property_docs = ["carrier-transport", "elastic"]
desired_props = {"carrier-transport": [], "elastic": []}

HS = HashinShtrikman(api_key=api_key, 
                     mp_contribs_project=mp_contribs_project, 
                     property_docs=property_docs, 
                     desired_props=desired_props, 
                     user_input=user_input,)

HS.set_HS_optim_params()
HS.print_table_of_best_designs()
HS.plot_optimization_results()
mat_1_ids, mat_2_ids = HS.get_material_matches()

print("Material 1 Matches:")
print(mat_1_ids)
print("Material 2 Matches:")
print(mat_2_ids)
# Out:
# Generation 0 of 5000
# Generation 1 of 5000
# Generation 2 of 5000
# Generation 3 of 5000
# Generation 4 of 5000
# Generation 5 of 5000
# Generation 6 of 5000
# Generation 7 of 5000
# Generation 8 of 5000
# Generation 9 of 5000
# Generation 10 of 5000
# Generation 11 of 5000
# Generation 12 of 5000
# Generation 13 of 5000
# Generation 14 of 5000
# Generation 15 of 5000
# Generation 16 of 5000
# Generation 17 of 5000
# Generation 18 of 5000
# Generation 19 of 5000
# Generation 20 of 5000
# Generation 21 of 5000
# Generation 22 of 5000
# Generation 23 of 5000
# Generation 24 of 5000
# Generation 25 of 5000
# Generation 26 of 5000
# Generation 27 of 5000
# Generation 28 of 5000
# Generation 29 of 5000
# Generation 30 of 5000
# Generation 31 of 5000
# Generation 32 of 5000
# Generation 33 of 5000
# Generation 34 of 5000
# Generation 35 of 5000
# Generation 36 of 5000
# Generation 37 of 5000
# Generation 38 of 5000
# Generation 39 of 5000
# Generation 40 of 5000
# Generation 41 of 5000
# ...
